# %%
# %cd "/content/drive/MyDrive/EECE 7205 Project/RGCL/RGCL-main"
# Out:
# /content/drive/MyDrive/EECE 7205 Project/RGCL/RGCL-main

# %%
# !pip install torch torchvision torchaudio
# !pip install git+https://github.com/openai/CLIP.git
# !pip install tqdm
# !pip install transformers
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-iad5yfj5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-iad5yfj5
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python3 read_pt.py
# Out:
# 2024-12-02 06:01:12.163029: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-02 06:01:12.182823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-02 06:01:12.189012: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-02 06:01:12.204819: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
